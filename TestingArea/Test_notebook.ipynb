# %%
ls

# %%
pwd

# %%
import pandas as pd
import numpy as np

# %%
cd Data/
# Out:
# /Users/andres/DocsNonCloud/Ironhack/MinorityRepo/Data

# %%
pwd

# %%
ls

# %%
cd DC/
# Out:
# /Users/andres/DocsNonCloud/Ironhack/MinorityRepo/Data/DC

# %%
pwd
# Out:
# '/Users/andres/DocsNonCloud/Ironhack/MinorityRepo/Data/DC'

# %%
incidents = "NIBRS_incident.csv"
offenders = "Data/DC_2019/NIBRS_OFFENDER.csv"
arrestees = "NIBRS_ARRESTEE.csv"
offenses = "NIBRS_OFFENSE.csv"
offenses_type = "NIBRS_OFFENSE_TYPE.csv"

# %%
df = pd.read_csv("NIBRS_incident.csv")
df
# Out:
#       DATA_YEAR  AGENCY_ID  INCIDENT_ID  NIBRS_MONTH_ID CARGO_THEFT_FLAG  \
# 0          2019       2244    121549353         8180938              NaN
# 1          2019       2244    121551726         8211586                N
# 2          2019       2244    121551728         8211586                N
# 3          2019       2244    119076144         8211586              NaN
# 4          2019       2244    119076145         8219248                N
# ...         ...        ...          ...             ...              ...
# 4100       2019       2244    123068595         8226910                N
# 4101       2019       2244    123068599         8226910              NaN
# 4102       2019       2244    123059902         8226910              NaN
# 4103       2019       2244    123068626         8226910              NaN
# 4104       2019       2244    123059907         8226910                N
#
#      SUBMISSION_DATE INCIDENT_DATE REPORT_DATE_FLAG  INCIDENT_HOUR  \
# ...

# %%
incident_id_list = df["INCIDENT_ID"]
list(incident_id_list)
# Out:
# [121549353,
#  121551726,
#  121551728,
#  119076144,
#  119076145,
#  119076147,
#  119076148,
#  116497388,
#  116497389,
#  116497390,
#  114331727,
#  114331731,
#  114346153,
#  114331745,
#  114331761,
#  114331855,
#  114331856,
#  114331857,
#  114331858,
#  114331861,
#  114331863,
#  114331865,
#  114331866,
#  114331867,
#  114346602,
#  114331868,
#  114331869,
#  114331871,
#  114331873,
#  114331874,
#  114331875,
#  114331877,
#  114331878,
#  114331879,
#  114331880,
#  114331722,
#  114331735,
#  114331746,
#  114331774,
#  114331775,
#  114346615,
#  114346616,
#  114346617,
#  114346618,
#  114346619,
#  114346620,
#  114346622,
#  114346623,
#  114346624,
#  114346626,
#  114346628,
#  114346629,
#  114346630,
#  114346631,
#  114346632,
#  114346635,
#  114346636,
#  114346637,
#  114346639,
#  114346640,
#  114346641,
#  118309105,
#  118309111,
#  114346644,
#  118309116,
#  114346647,
#  118309117,
#  114346649,
#  114346650,
#  114346651,
#  114346652,
# ...

# %%
offenses_df = pd.read_csv(offenses)
offenses_df
# Out:
#       DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0          2019   147151350    121549353               18
# 1          2019   147151354    121551726               40
# 2          2019   147151356    121551728               40
# 3          2019   144331220    119076144               18
# 4          2019   144331221    119076145               45
# ...         ...         ...          ...              ...
# 4505       2019   148901551    123068599               51
# 4506       2019   148906540    123059902                5
# 4507       2019   148901580    123068626               51
# 4508       2019   148906547    123059907                5
# 4509       2019   148906546    123059907               14
#
#      ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                        C            1                   NaN
# 1                        C            1                   NaN
# 2                        C           13                   NaN
# ...

# %%
offenses_type_df = pd.read_csv(offenses_type)
offenses_type_df = offenses_type_df.iloc[:,[0,8]]
offenses_type_df
# Out:
#     OFFENSE_TYPE_ID OFFENSE_GROUP
# 0                58             A
# 1                 1             A
# 2                 2             A
# 3                 3             A
# 4                 4             A
# ..              ...           ...
# 81               68             A
# 82               36             A
# 83               50             A
# 84               10             B
# 85               48             B
#
# [86 rows x 2 columns]

# %%
new_df = pd.merge(offenses_df, offenses_type_df, on=['OFFENSE_TYPE_ID'], how="left")

# %%
new_df[new_df["OFFENSE_GROUP"]=="A"]
# Out:
#       DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0          2019   147151350    121549353               18
# 1          2019   147151354    121551726               40
# 2          2019   147151356    121551728               40
# 3          2019   144331220    119076144               18
# 4          2019   144331221    119076145               45
# ...         ...         ...          ...              ...
# 4505       2019   148901551    123068599               51
# 4506       2019   148906540    123059902                5
# 4507       2019   148901580    123068626               51
# 4508       2019   148906547    123059907                5
# 4509       2019   148906546    123059907               14
#
#      ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                        C            1                   NaN
# 1                        C            1                   NaN
# 2                        C           13                   NaN
# ...

# %%
pwd
# Out:
# '/Users/andres/DocsNonCloud/Ironhack/MinorityRepo/Data/DC_2019'

# %%
cd /Users/andres/DocsNonCloud/Ironhack/MinorityRepo
# Out:
# /Users/andres/DocsNonCloud/Ironhack/MinorityRepo

# %%
pwd
# Out:
# '/Users/andres/DocsNonCloud/Ironhack/MinorityRepo'

# %%
df = pd.read_csv("Data/DC_2019/NIBRS_OFFENSE.csv")
df
# Out:
#       DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0          2019   147151350    121549353               18
# 1          2019   147151354    121551726               40
# 2          2019   147151356    121551728               40
# 3          2019   144331220    119076144               18
# 4          2019   144331221    119076145               45
# ...         ...         ...          ...              ...
# 4505       2019   148901551    123068599               51
# 4506       2019   148906540    123059902                5
# 4507       2019   148901580    123068626               51
# 4508       2019   148906547    123059907                5
# 4509       2019   148906546    123059907               14
#
#      ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                        C            1                   NaN
# 1                        C            1                   NaN
# 2                        C           13                   NaN
# ...

# %%
(
pd.read_csv(offenders)["INCIDENT_ID"]
).nunique()
# Out:
# 4105

# %%
15786-7674
# Out:
# 8112

# %%
df[df["OFFENSE_TYPE_ID"]==18]
# Out:
#       DATA_YEAR  OFFENSE_ID  INCIDENT_ID  OFFENSE_TYPE_ID  \
# 0          2019   147151350    121549353               18
# 3          2019   144331220    119076144               18
# 5          2019   144331222    119076145               18
# 33         2019   139559032    114331874               18
# 41         2019   139576271    114331735               18
# ...         ...         ...          ...              ...
# 4415       2019   145495763    120089669               18
# 4416       2019   145495770    120089673               18
# 4441       2019   145495853    120089754               18
# 4448       2019   145495711    120089622               18
# 4501       2019   148906520    123059888               18
#
#      ATTEMPT_COMPLETE_FLAG  LOCATION_ID  NUM_PREMISES_ENTERED  \
# 0                        C            1                   NaN
# 3                        A            1                   NaN
# 5                        C           13                   NaN
# ...

# %%
(pd.read_csv("Data/DC_2019/NIBRS_RELATIONSHIP.csv")[["RELATIONSHIP_TYPE_ID","RELATIONSHIP_NAME"]]
 .sort_values(["RELATIONSHIP_TYPE_ID"])
)
# Out:
#     RELATIONSHIP_TYPE_ID                                  RELATIONSHIP_NAME
# 22                     1                             Victim Was Stepsibling
# 21                     1                              Victim Was Stepparent
# 20                     1                                  Victim Was Spouse
# 4                      1                                   Victim Was Child
# 5                      1                       Victim Was Common-Law Spouse
# 19                     1                               Victim Was Stepchild
# 18                     1                                 Victim Was Sibling
# 16                     1                                  Victim Was Parent
# 9                      1                              Victim Was Grandchild
# 10                     1                             Victim Was Grandparent
# 12                     1                                  Victim Was In-law
# ...
